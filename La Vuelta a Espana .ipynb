# %% [markdown]
# # La Vuelta a Espana (2001-2022)

# %%
import requests
from bs4 import BeautifulSoup as bs
import numpy as np
import pandas as pd

def fetch_url(url):
    '''
    Returns the content of the `url`.
    '''
    r = requests.get(url)
    if r.status_code == 200:
        return r.content
    raise Exception('Request Error')

# %% [markdown]
# ## Scrape Stage Data

# %%
base_url = 'https://www.procyclingstats.com/race/vuelta-a-espana/{}/stage-{}'
# Initialize data structures. 
# Results contains individual stages, including time trials. TTT are team time trials. Info has details about the stages.
results = pd.DataFrame()
ttt = pd.DataFrame()
info = []

for year in range(2001, 2023):
    for stage in range(1, 22):
        url = base_url.format(str(year), str(stage))
        # Access url with BeautifulSoup.
        stats = bs(fetch_url(url), 'html.parser')
        
        # Info
        infolist = []
        ul = stats.find('ul', class_ = 'infolist')
        # There are not always 21 stages.
        if ul is None:
            break
            
        for index, li in enumerate(ul.find_all('li', recursive = False)[:-1]):
            if index == 7:
                # Parcours Type
                infolist.append(li.find_all('span')[0]['class'])
            else:
                infolist.append(li.find_all('div', recursive = False)[-1].text)
                
        infolist.append(stage)
        info.append(infolist)
        
        # Stage Results.
        description = stats.find('option', value = url[32:]).text
        
        if 'TTT' in description:
            standings = stats.find_all('table', class_ = 'results-ttt')[0]
            standings = pd.read_html(str(standings), flavor = 'bs4', header = [0])[0]
            standings['year'] = year
            standings['stage'] = stage
        
            ttt = pd.concat([ttt, standings], axis = 0)
            
        else:
            standings = stats.find_all('table', class_ = 'results basic moblist10')[0]
            standings = pd.read_html(str(standings), flavor = 'bs4', header = [0])[0]
            
            if 'ITT' in description:
                standings['type'] = 'ITT'
            elif 'prologue' in description.lower():
                standings['type'] = 'Prologue'
            else:
                standings['type'] = 'Road Race'
                
            standings['year'] = year
            standings['stage'] = stage
        
            results = pd.concat([results, standings], axis = 0)

# %%
ttt.to_csv('ttt_raw', index = False)
results.to_csv('results_raw', index = False)

# %% [markdown]
# ## Clean `info`

# %%
info_cols = ['Date', 'Start', 'Speed', 'Category', 'Distance', 'Points_Scale', 'UCI_Scale', 'Parcour_Type', 'Profile_Score',
             'Vertical_Meters', 'Departure', 'Arrival', 'Race_Ranking', 'List_Quality', 'Won_How', 'stage']
info_df = pd.DataFrame(info, columns = info_cols)
info_df.to_csv('info_raw', index = False)
info_df.tail()
# Out:
#                   Date   Start        Speed        Category  Distance  \
# 454  07 September 2022  13:21   43.773 km/h  ME - Men Elite  162.3 km
# 455  08 September 2022  12:19   40.381 km/h  ME - Men Elite    192 km
# 456  09 September 2022  14:03    41.66 km/h  ME - Men Elite  138.3 km
# 457  10 September 2022  12:45    38.57 km/h  ME - Men Elite    181 km
# 458  11 September 2022  17:26   39.577 km/h  ME - Men Elite   96.7 km
#
#     Points_Scale                   UCI_Scale         Parcour_Type  \
# 454   GT.B.Stage  UCI.WR.GT.B.Stage - TM2022  [icon, profile, p1]
# 455   GT.B.Stage  UCI.WR.GT.B.Stage - TM2022  [icon, profile, p5]
# 456   GT.B.Stage  UCI.WR.GT.B.Stage - TM2022  [icon, profile, p4]
# 457   GT.B.Stage  UCI.WR.GT.B.Stage - TM2022  [icon, profile, p4]
# 458   GT.B.Stage  UCI.WR.GT.B.Stage - TM2022  [icon, profile, p1]
#
#     Profile_Score Vertical_Meters             Departure  \
# 454           161            2755               Aracena
# 455           214            3680              Trujillo
# 456           101            2278  Talavera de la Reina
# 457           216            3977           Moralzarzal
# 458            10             773             Las Rozas
#
#                     Arrival Race_Ranking List_Quality                Won_How  \
# 454  Monasterio de Tentudía            9          970  Sprint of small group
# 455        Alto del Piornal            9          970  Sprint of small group
# 456    Talavera de la Reina            9          970  Sprint of large group
# 457   Puerto de Navacerrada            9          970            7.2 km solo
# 458                  Madrid            9          970  Sprint of large group
#
#      stage
# 454     17
# 455     18
# 456     19
# 457     20
# 458     21

# %%
info_df.replace({'':np.nan}, inplace = True)

# %%
(info_df['Start'] == '-').sum()
# Out:
# 316

# %%
info_df['Start'] = info_df['Start'].replace({'-':np.nan})

# %%
info_df['day'] = info_df['Date'].str[:2].astype(int)
info_df['Month'] = info_df['Date'].str.extract('([a-zA-z]+)')
info_df['year'] = info_df['Date'].str[-4:].astype(int)
info_df.drop('Date', axis = 1, inplace = True)

# %%
# All speeds in km/h.
assert info_df['Speed'].str[-4:].nunique() == 1

# %%
info_df['Speed'] = info_df['Speed'].str[:-4].astype(float)

# %%
info_df['Category'].value_counts()
# Out:
# ME - Men Elite    459
# Name: Category, dtype: int64

# %%
info_df.drop('Category', axis = 1, inplace = True)

# %%
# All distances in km.
assert info_df['Distance'].str[-2:].nunique() == 1

# %%
info_df['Distance'] = info_df['Distance'].str[:-2].astype(float)

# %%
info_df.drop(['Points_Scale', 'UCI_Scale'], axis = 1, inplace = True)

# %%
info_df['Parcour_Type'].value_counts().sort_index()
# Out:
# [icon, profile, p1]    155
# [icon, profile, p2]     96
# [icon, profile, p3]     48
# [icon, profile, p4]     32
# [icon, profile, p5]    128
# Name: Parcour_Type, dtype: int64

# %%
info_df['Parcour_Type'] = info_df['Parcour_Type'].str[-1]

# %%
info_df['Race_Ranking'].value_counts(dropna = False)
# Out:
# 0     399
# 10     21
# 9      21
# 14     18
# Name: Race_Ranking, dtype: int64

# %%
info_df.drop('Race_Ranking', axis = 1, inplace = True)

# %%
info_df['Won_How'].unique()
# Out:
# array(['Time Trial', 'Sprint of large group', 'Sprint of small group',
#        '? km solo', 'Sprint a deux', '35 km solo', '40 km solo',
#        '10 km solo', '2 km solo', '0.8 km solo', '4 km solo',
#        '25 km solo', '5 km solo', '44 km solo', '51 km solo',
#        '15 km solo', '12 km solo', '1 km solo', '20 km solo',
#        '16 km solo', '0.5 km solo', '0.4 km solo', '4.3 km solo',
#        '162 km solo', '7 km solo', '24.5 km solo', '2.5 km solo',
#        '7.5 km solo', '105 km solo', '8 km solo', '11 km solo',
#        '26 km solo', '9 km solo', '22 km solo', '3.5 km solo',
#        '3 km solo', '0.7 km solo', '5.5 km solo', '28 km solo',
#        '22.3 km solo', '0.6 km solo', '4.8 km solo', '1.1 km solo',
#        '6 km solo', '13 km solo', '21 km solo', '11.3 km solo',
#        '13.6 km solo', '4.6 km solo', '1.5 km solo', '47 km solo',
#        '24 km solo', '43 km solo', '6.5 km solo', '1.8 km solo',
#        '5.3 km solo', '8.8 km solo', '29 km solo', '0.9 km solo',
#        '114 km solo', '1.2 km solo', '3.7 km solo', '0.2 km solo',
#        '18.5 km solo', '2.7 km solo', '9.6 km solo', '1.3 km solo',
#        '2.2 km solo', '18 km solo', '6.6 km solo', '53 km solo',
#        '39 km solo', '14 km solo', '0.3 km solo', '2.8 km solo',
#        '0.77 km solo', '3.2 km solo', '71.1 km solo', '19 km solo',
#        '87.3 km solo', '1.7 km solo', '15.4 km solo', '5.9 km solo',
#        '1.9 km solo', '3.3 km solo', '7.2 km solo'], dtype=object)

# %%
info_df.head()
# Out:
#   Start   Speed  Distance Parcour_Type Profile_Score Vertical_Meters  \
# 0   NaN  49.420      12.3           p1             2              95
# 1   NaN  41.181     147.2           p1            12             673
# 2   NaN  46.108     140.5           p1             3             567
# 3   NaN  42.039     175.0           p2            50            1942
# 4   NaN  37.306     160.8           p5           282            2946
#
#      Departure             Arrival List_Quality                Won_How  stage  \
# 0   Salamanca            Salamanca          927             Time Trial      1
# 1   Salamanca           Valladolid          927  Sprint of large group      2
# 2  Valladolid                 León          927  Sprint of large group      3
# 3        León                Gijón          927  Sprint of small group      4
# 4       Gijón   Lagos de Covadonga          927              ? km solo      5
#
#    day      Month  year
# 0    8  September  2001
# 1    9  September  2001
# 2   10  September  2001
# 3   11  September  2001
# 4   12  September  2001

# %% [markdown]
# ## Clean `ttt`

# %%
ttt.reset_index(drop = True, inplace = True)

# %%
ttt.head(50)
# Out:
#     Pos.                         Team   Time Timegap   Speed  PCS points  \
# 0    1.0            O.N.C.E. - Eroski  26:21     NaN  55.787         NaN
# 1    2.0            US Postal Service  26:35    0:14  55.298         NaN
# 2    3.0         Kelme - Costa Blanca  26:36    0:15  55.263         NaN
# 3    4.0                 Team Telekom  26:39    0:18  55.159         NaN
# 4    5.0                Fassa Bortolo  26:44    0:23  54.988         NaN
# 5    6.0                      Cofidis  26:47    0:26  54.885         NaN
# 6    7.0                 iBanesto.com  26:48    0:27  54.851         NaN
# 7    8.0                   Team Coast  27:00    0:39  54.444         NaN
# 8    9.0            Mapei - Quickstep  27:03    0:42  54.344         NaN
# 9   10.0               Acqua & Sapone  27:04    0:43  54.310         NaN
# 10  11.0       Phonak Hearing Systems  27:08    0:47  54.177         NaN
# 11  12.0              Lampre - Daikin  27:15    0:54  53.945         NaN
# 12  13.0               Milaneza - Mss  27:15    0:54  53.945         NaN
# 13  14.0           Domo - Farm Frites  27:20    0:59  53.780         NaN
# 14  15.0          Euskaltel - Euskadi  27:24    1:03  53.650         NaN
# 15  16.0        Saeco - Longoni Sport  27:34    1:13  53.325         NaN
# 16  17.0                Tacconi Sport  27:34    1:13  53.325         NaN
# 17  18.0            BigMat - Auber 93  27:37    1:16  53.229         NaN
# 18  19.0   Jazztel - Costa de Almeria  27:42    1:21  53.069         NaN
# 19  20.0                      Alessio  27:45    1:24  52.973         NaN
# 20  21.0              AG2R Prévoyance  27:47    1:26  52.909         NaN
# 21  22.0  Colchon Relax - Fuenlabrada  27:52    1:31  52.751         NaN
# 22  23.0     Index - Alexia Alluminio  28:59    2:38  50.719         NaN
# 23   1.0            O.N.C.E. - Eroski  32:01     NaN  56.221         NaN
# 24   NaN                VICIOSO Ángel    NaN     NaN     NaN        40.0
# 25   NaN           AZEVEDO José Bento    NaN     NaN     NaN        40.0
# 26   NaN       SERRANO Marcos Antonio    NaN     NaN     NaN        40.0
# 27   NaN    GONZÁLEZ DE GALDEANO Igor    NaN     NaN     NaN        40.0
# 28   NaN                   HRUŠKA Jan    NaN     NaN     NaN        40.0
# 29   NaN            RODRÍGUEZ Joaquim    NaN     NaN     NaN        40.0
# 30   NaN                 NOZAL Isidro    NaN     NaN     NaN        40.0
# 31   2.0            US Postal Service  32:11    0:10  55.930         NaN
# 32   NaN                BARRY Michael    NaN     NaN     NaN        32.0
# 33   NaN              HINCAPIE George    NaN     NaN     NaN        32.0
# 34   NaN                WHITE Matthew    NaN     NaN     NaN        32.0
# 35   NaN               JOACHIM Benoît    NaN     NaN     NaN        32.0
# 36   NaN               BELTRÁN Manuel    NaN     NaN     NaN        32.0
# 37   NaN                HERAS Roberto    NaN     NaN     NaN        32.0
# 38   NaN                 LANDIS Floyd    NaN     NaN     NaN        32.0
# 39   NaN            RUBIERA José Luis    NaN     NaN     NaN        32.0
# 40   NaN             VAN HEESWIJK Max    NaN     NaN     NaN        32.0
# 41   3.0                 iBanesto.com  32:25    0:24  55.527         NaN
# 42   NaN               JIMÉNEZ Eladio    NaN     NaN     NaN        24.0
# 43   NaN            MANCEBO Francisco    NaN     NaN     NaN        24.0
# 44   NaN                    OSA Aitor    NaN     NaN     NaN        24.0
# 45   NaN          MERCADO Juan Miguel    NaN     NaN     NaN        24.0
# 46   NaN   GARCÍA ACOSTA José Vicente    NaN     NaN     NaN        24.0
# 47   NaN                     OSA Unai    NaN     NaN     NaN        24.0
# 48   NaN            ARRIETA José Luis    NaN     NaN     NaN        24.0
# 49   NaN             PIEPOLI Leonardo    NaN     NaN     NaN        24.0
#
#     UCI points  year  stage
# 0          NaN  2002      1
# 1          NaN  2002      1
# 2          NaN  2002      1
# 3          NaN  2002      1
# 4          NaN  2002      1
# 5          NaN  2002      1
# 6          NaN  2002      1
# 7          NaN  2002      1
# 8          NaN  2002      1
# 9          NaN  2002      1
# 10         NaN  2002      1
# 11         NaN  2002      1
# 12         NaN  2002      1
# 13         NaN  2002      1
# 14         NaN  2002      1
# 15         NaN  2002      1
# 16         NaN  2002      1
# 17         NaN  2002      1
# 18         NaN  2002      1
# 19         NaN  2002      1
# 20         NaN  2002      1
# 21         NaN  2002      1
# 22         NaN  2002      1
# 23         NaN  2003      1
# 24         NaN  2003      1
# 25         NaN  2003      1
# 26         NaN  2003      1
# 27         NaN  2003      1
# 28         NaN  2003      1
# 29         NaN  2003      1
# 30         NaN  2003      1
# 31         NaN  2003      1
# 32         NaN  2003      1
# 33         NaN  2003      1
# 34         NaN  2003      1
# 35         NaN  2003      1
# 36         NaN  2003      1
# 37         NaN  2003      1
# 38         NaN  2003      1
# 39         NaN  2003      1
# 40         NaN  2003      1
# 41         NaN  2003      1
# 42         NaN  2003      1
# 43         NaN  2003      1
# 44         NaN  2003      1
# 45         NaN  2003      1
# 46         NaN  2003      1
# 47         NaN  2003      1
# 48         NaN  2003      1
# 49         NaN  2003      1

# %%
ttt.shape
# Out:
# (2971, 9)

# %%
ttt.drop(['PCS points', 'UCI points'], axis = 1, inplace = True)

# %%
ttt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2971 entries, 0 to 2970
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Pos.     326 non-null    float64
#  1   Team     2971 non-null   object
#  2   Time     326 non-null    object
#  3   Timegap  311 non-null    object
#  4   Speed    326 non-null    float64
#  5   year     2971 non-null   int64
#  6   stage    2971 non-null   int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 162.6+ KB

# %%
import math

# Create a dataframe with the rider names of each team.
riders = []
for i, row in ttt.iterrows():
    if math.isnan(row['Pos.']):
        # Null position indicate rider row.
        names.append(row['Team'])
    else:
        # Non-null posotion is a team entry.
        if i != 0:
            data.append(names)
            riders.append(data)
        data = [row['Team'], row['year'], row['stage']]
        names = []
        
data.append(names)
riders.append(data)
riders = pd.DataFrame(riders, columns = ['Team', 'year', 'stage', 'riders'])
riders.tail()
# Out:
#                                        Team  year  stage  \
# 321  Intermarché - Wanty - Gobert Matériaux  2022      1
# 322                     Euskaltel - Euskadi  2022      1
# 323                            Lotto Soudal  2022      1
# 324                                 Cofidis  2022      1
# 325                               Burgos-BH  2022      1
#
#                                                 riders
# 321  [TAARAMÄE Rein, HIRT Jan, POZZOVIVO Domenico, ...
# 322  [MATÉ Luis Ángel +0:17, MARTÍN Gotzon, BOU Joa...
# 323  [BEULLENS Cedric, DRIZNERS Jarrad, VAN GILS Ma...
# 324  [VILLELLA Davide, CHAMPION Thomas +0:59, FERNÁ...
# 325  [NAVARRO Daniel, BOL Jetse, EZQUERRA Jesús, LA...

# %%
# Filter `ttt` dataframe to have only teams in rows, and add team members information.
ttt = ttt[ttt[['Pos.']].notnull().all(1)]
merge_cols = ['Team', 'year', 'stage']
ttt = ttt.merge(riders, how = 'left', left_on = merge_cols, right_on = merge_cols)
ttt.tail()
# Out:
#      Pos.                                    Team   Time Timegap   Speed  \
# 321  19.0  Intermarché - Wanty - Gobert Matériaux  26:05    1:25  53.597
# 322  20.0                     Euskaltel - Euskadi  26:12    1:32  53.359
# 323  21.0                            Lotto Soudal  26:29    1:49  52.788
# 324  22.0                                 Cofidis  26:30    1:50  52.755
# 325  23.0                               Burgos-BH  26:38    1:58  52.491
#
#      year  stage                                             riders
# 321  2022      1  [TAARAMÄE Rein, HIRT Jan, POZZOVIVO Domenico, ...
# 322  2022      1  [MATÉ Luis Ángel +0:17, MARTÍN Gotzon, BOU Joa...
# 323  2022      1  [BEULLENS Cedric, DRIZNERS Jarrad, VAN GILS Ma...
# 324  2022      1  [VILLELLA Davide, CHAMPION Thomas +0:59, FERNÁ...
# 325  2022      1  [NAVARRO Daniel, BOL Jetse, EZQUERRA Jesús, LA...

# %%
ttt.isnull().sum()[ttt.isnull().sum() > 0]
# Out:
# Timegap    15
# dtype: int64

# %%
# Timegap is null for teams that rank first.
ttt['Timegap'].fillna('0:00', inplace = True)

# %% [markdown]
# ## Clean `results`

# %%
results = pd.read_csv('results_raw', low_memory = False)

# %%
results.tail()
# Out:
#        Rnk     GC   Timelag  BIB  H2H  \
# 75981  130  110.0  +4:33:12  156  NaN
# 75982  131  117.0  +4:48:07  162  NaN
# 75983  132  107.0  +4:23:20  183  NaN
# 75984  133   94.0  +3:59:57  212  NaN
# 75985  134   97.0  +4:03:39  166  NaN
#
#                                           Rider  Age                 Team  \
# 75981           HVIDEBERG Jonas IversbyTeam DSM   23             Team DSM
# 75982             CATALDO DarioTrek - Segafredo   37     Trek - Segafredo
# 75983          JANSSENS JimmyAlpecin-Deceuninck   33   Alpecin-Deceuninck
# 75984  AZPARREN Xabier MikelEuskaltel - Euskadi   23  Euskaltel - Euskadi
# 75985          LÓPEZ Juan PedroTrek - Segafredo   25     Trek - Segafredo
#
#        UCI  Pnt Unnamed: 10      Time  Avg       type  year  stage
# 75981  NaN  NaN         NaN  4:444:44  NaN  Road Race  2022     21
# 75982  NaN  NaN         NaN    ,,4:44  NaN  Road Race  2022     21
# 75983  NaN  NaN         NaN  4:464:46  NaN  Road Race  2022     21
# 75984  NaN  NaN         NaN  5:305:30  NaN  Road Race  2022     21
# 75985  NaN  NaN         NaN  5:455:45  NaN  Road Race  2022     21

# %%
results.reset_index(drop = True, inplace = True)

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75986 entries, 0 to 75985
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rnk          75986 non-null  object
#  1   GC           73757 non-null  float64
#  2   Timelag      73757 non-null  object
#  3   BIB          75986 non-null  int64
#  4   H2H          0 non-null      float64
#  5   Rider        75986 non-null  object
#  6   Age          75986 non-null  int64
#  7   Team         75889 non-null  object
#  8   UCI          1264 non-null   float64
#  9   Pnt          6651 non-null   float64
#  10  Unnamed: 10  204 non-null    object
#  11  Time         75986 non-null  object
#  12  Avg          6587 non-null   float64
#  13  type         75986 non-null  object
#  14  year         75986 non-null  int64
#  15  stage        75986 non-null  int64
# dtypes: float64(5), int64(4), object(7)
# memory usage: 9.3+ MB

# %%
out = ['DNF', 'DNS', 'OTL', 'DSQ']
for col in ['GC', 'Timelag']:
    # No GC or Timelag for riders who do not finish the stage.
    results[col] = results.apply(lambda row: '-' if row['Rnk'] in out else row[col], axis = 1)

# %%
results.drop(['H2H', 'UCI', 'Pnt', 'Avg'], axis = 1, inplace = True)

# %%
# Rider Column has the Team column appended to it. Let's check if those rows + the ones with null teams add to the total.
team_in_rider = results.apply(lambda x: str(x.Team) in str(x.Rider), axis = 1)
assert sum(team_in_rider) + results['Team'].isnull().sum() == results.shape[0]

# %%
# Remove Team name from Rider column.
results['Rider'] = results.apply(lambda x: str(x.Rider).removesuffix(str(x.Team)), axis = 1)

# %%
results[results['Unnamed: 10'].notnull()]
# Out:
#        Rnk     GC   Timelag  BIB               Rider  Age  \
# 69468    1  136.0     +2:07   26    PHILIPSEN Jasper   23
# 69469    2   48.0     +0:45   91      JAKOBSEN Fabio   24
# 69470    3    3.0     +0:10  181    MATTHEWS Michael   30
# 69472    5    2.0     +0:04   32       ARANBURU Alex   25
# 69506   39   50.0     +0:45   97  VAN LERBERGHE Bert   28
# ...    ...    ...       ...  ...                 ...  ...
# 75853    2  102.0  +4:14:48  167       PEDERSEN Mads   26
# 75854    3  111.0  +4:33:23  172    ACKERMANN Pascal   28
# 75883   32    2.0     +2:02  124           MAS Enric   27
# 75956  105   14.0    +29:19   81     CARAPAZ Richard   29
# 75957  106  106.0  +4:19:29  157   NIEUWENHUIS Joris   26
#
#                           Team Unnamed: 10        Time       type  year  stage
# 69468            Alpecin-Fenix         10″  3:58:5710″  Road Race  2021      2
# 69469  Deceuninck - Quick Step          9″    ,,0:009″  Road Race  2021      2
# 69470        Team BikeExchange          4″    ,,0:004″  Road Race  2021      2
# 69472    Astana - Premier Tech          2″    ,,0:002″  Road Race  2021      2
# 69506  Deceuninck - Quick Step          1″    ,,0:001″  Road Race  2021      2
# ...                        ...         ...         ...        ...   ...    ...
# 75853         Trek - Segafredo          6″    ,,0:006″  Road Race  2022     21
# 75854        UAE Team Emirates          4″    ,,0:004″  Road Race  2022     21
# 75883            Movistar Team          3″    ,,0:113″  Road Race  2022     21
# 75956         INEOS Grenadiers          1″    ,,1:131″  Road Race  2022     21
# 75957                 Team DSM          2″  1:221:222″  Road Race  2022     21
#
# [204 rows x 12 columns]

# %%
# The `Unnamed: 10` column represents time bonifications.
results.rename({'Unnamed: 10':'Bonus'}, axis = 1, inplace = True)
results['Bonus'].str[-1].value_counts()
# Out:
# ″    204
# Name: Bonus, dtype: int64

# %%
# As happened with riders and teams, the `Time` column has Bonus appended to it.
bonus_non_null = results.query('Bonus.notnull()')
bonus_at_time = results.apply(lambda x: str(x['Time']).endswith(str(x['Bonus'])), axis = 1)
assert sum(bonus_at_time) == bonus_non_null.shape[0]

# %%
# Delete bonification from time.
results['Time'] = results.apply(lambda x: str(x['Time']).removesuffix(str(x['Bonus'])), axis = 1).astype(str)

# %%
# Null bonus means zero time benefit. Delete the apostrophe at the end.
results['Bonus'] = results['Bonus'].fillna('00').str[:-1].astype(int)

# %%
results.iloc[:15]['Time']
# Out:
# 0      0:14:56
# 1     0:010:01
# 2     0:060:06
# 3     0:170:17
# 4     0:230:23
# 5     0:240:24
# 6     0:250:25
# 7     0:260:26
# 8       ,,0:26
# 9     0:280:28
# 10    0:300:30
# 11    0:310:31
# 12    0:320:32
# 13    0:330:33
# 14      ,,0:33
# Name: Time, dtype: object

# %%
# Two observations from above: 
# Equal times as previous rider start with a ','. Some times are duplicated.
double_time = results[results.apply(lambda x: not x['Time'].startswith(',') 
                                    and x['Time'] != '-' 
                                    and x['Rnk'] != '1', axis = 1)]
double_time.head()
# Out:
#   Rnk   GC Timelag  BIB                      Rider  Age                  Team  \
# 1   2  2.0   +0:01  102            BOTERO Santiago   28  Kelme - Costa Blanca
# 2   3  3.0   +0:06    6            LEIPHEIMER Levi   27     US Postal Service
# 3   4  4.0   +0:17  155  GONZÁLEZ DE GALDEANO Igor   27     O.N.C.E. - Eroski
# 4   5  5.0   +0:23  152              BELOKI Joseba   28     O.N.C.E. - Eroski
# 5   6  6.0   +0:24   86                PLAZA David   31               Festina
#
#    Bonus      Time type  year  stage
# 1      0  0:010:01  ITT  2001      1
# 2      0  0:060:06  ITT  2001      1
# 3      0  0:170:17  ITT  2001      1
# 4      0  0:230:23  ITT  2001      1
# 5      0  0:240:24  ITT  2001      1

# %%
# Confirm all specified times are doubled.
suffix_num = double_time[double_time['Time'].map(
    lambda t: t[:int(len(t) / 2)] != t[int(len(t) / 2):])][['Time', 'Bonus']]
assert suffix_num.shape[0] == 0

# %%
results[results['Rnk'] == '1']
# Out:
#       Rnk     GC   Timelag  BIB                  Rider  Age  \
# 0       1    1.0     +0:00   41           MILLAR David   24
# 189     1  118.0     +1:40  201             ZABEL Erik   31
# 378     1   79.0     +1:40  201             ZABEL Erik   31
# 566     1   43.0     +1:23  201             ZABEL Erik   31
# 753     1    2.0     +0:15   29    MERCADO Juan Miguel   23
# ...    ..    ...       ...  ...                    ...  ...
# 75304   1    9.0     +9:33   61         URÁN Rigoberto   35
# 75446   1    1.0     +0:00  134        EVENEPOEL Remco   22
# 75584   1  102.0  +3:43:22  167          PEDERSEN Mads   26
# 75718   1   14.0    +28:18   81        CARAPAZ Richard   29
# 75852   1  126.0  +5:09:31  177  MOLANO Juan Sebastián   27
#
#                               Team  Bonus     Time       type  year  stage
# 0                          Cofidis      0  0:14:56        ITT  2001      1
# 189                   Team Telekom      0  3:34:28  Road Race  2001      2
# 378                   Team Telekom      0  3:02:50  Road Race  2001      3
# 566                   Team Telekom      0  4:09:46  Road Race  2001      4
# 753                   iBanesto.com      0  4:18:37  Road Race  2001      5
# ...                            ...    ...      ...        ...   ...    ...
# 75304        EF Education-EasyPost     22  3:42:28  Road Race  2022     17
# 75446  Quick-Step Alpha Vinyl Team     10  4:45:17  Road Race  2022     18
# 75584             Trek - Segafredo     10  3:19:11  Road Race  2022     19
# 75718             INEOS Grenadiers     13  4:41:34  Road Race  2022     20
# 75852            UAE Team Emirates     10  2:26:36  Road Race  2022     21
#
# [445 rows x 12 columns]

# %%
def clean_time(row):
    if row['Time'].startswith(','):
        if row['Rnk'] == '2':
            # Same time as first rank.
            return '+0:00'
        else:
            # To be filled later.
            return np.nan
    elif row['Time'] == '-':
        return '-'
    
    t = str(row['Time'])
        
    if row['Rnk'] == '1':
        return t
    else:
        return '+' + t[:int(len(t) / 2)]
    
    
    
results['Time'] = results.apply(clean_time, axis = 1)

# %%
# Nulls get same time as row above.
results['Time'].fillna(method = 'ffill', inplace = True)

# %%
# Check added times have at most 5 characters (no hours).
assert results.apply(lambda x: len(str(x['Time'])) > 6 and x['Rnk'] != '1', axis = 1).sum() == 0

# %%
results
# Out:
#        Rnk     GC   Timelag  BIB                      Rider  Age  \
# 0        1    1.0     +0:00   41               MILLAR David   24
# 1        2    2.0     +0:01  102            BOTERO Santiago   28
# 2        3    3.0     +0:06    6            LEIPHEIMER Levi   27
# 3        4    4.0     +0:17  155  GONZÁLEZ DE GALDEANO Igor   27
# 4        5    5.0     +0:23  152              BELOKI Joseba   28
# ...    ...    ...       ...  ...                        ...  ...
# 75981  130  110.0  +4:33:12  156    HVIDEBERG Jonas Iversby   23
# 75982  131  117.0  +4:48:07  162              CATALDO Dario   37
# 75983  132  107.0  +4:23:20  183             JANSSENS Jimmy   33
# 75984  133   94.0  +3:59:57  212      AZPARREN Xabier Mikel   23
# 75985  134   97.0  +4:03:39  166           LÓPEZ Juan Pedro   25
#
#                        Team  Bonus     Time       type  year  stage
# 0                   Cofidis      0  0:14:56        ITT  2001      1
# 1      Kelme - Costa Blanca      0    +0:01        ITT  2001      1
# 2         US Postal Service      0    +0:06        ITT  2001      1
# 3         O.N.C.E. - Eroski      0    +0:17        ITT  2001      1
# 4         O.N.C.E. - Eroski      0    +0:23        ITT  2001      1
# ...                     ...    ...      ...        ...   ...    ...
# 75981              Team DSM      0    +4:44  Road Race  2022     21
# 75982      Trek - Segafredo      0    +4:44  Road Race  2022     21
# 75983    Alpecin-Deceuninck      0    +4:46  Road Race  2022     21
# 75984   Euskaltel - Euskadi      0    +5:30  Road Race  2022     21
# 75985      Trek - Segafredo      0    +5:45  Road Race  2022     21
#
# [75986 rows x 12 columns]

# %% [markdown]
# ## Save Stages Data

# %%
info_df.to_csv('info', index = False)
ttt.to_csv('ttt', index = False)
results.to_csv('results', index = False)

# %% [markdown]
# ## Scrape Final Classifications Data

# %%
base_url = 'https://www.procyclingstats.com/race/vuelta-a-espana/{}/{}'

# General, Points, and Mountain Classifications.
gc = pd.DataFrame()
points = pd.DataFrame()
kom = pd.DataFrame()

for year in range(2001, 2023):
    # General
    url = base_url.format(year, 'gc')
    tables = bs(fetch_url(url), 'html.parser').find_all('table', class_ = 'results basic moblist10')
    
    current_gc = pd.read_html(str(tables[1]), flavor = 'bs4', header = [0])[0]
    current_points = pd.read_html(str(tables[2]), flavor = 'bs4', header = [0])[0]
    current_kom = pd.read_html(str(tables[3]), flavor = 'bs4', header = [0])[0]
    
    for x in [current_gc, current_points, current_kom]:
        x['year'] = year
    
    gc = pd.concat([gc, current_gc], axis = 0)
    points = pd.concat([points, current_points], axis = 0)
    kom = pd.concat([kom, current_kom], axis = 0)

# %%
gc.to_csv('gc_raw', index = False)
points.to_csv('points_raw', index = False)
kom.to_csv('kom_raw', index = False)

# %% [markdown]
# ## Clean `gc`, `points`, and `kom`

# %%
gc.head()
# Out:
#    Rnk  Prev ▼▲  BIB  H2H                              Rider  Age  \
# 0    1   1.0  -   81  NaN           CASERO Ángel LuisFestina   29
# 1    2   NaN  -  101  NaN  SEVILLA ÓscarKelme - Costa Blanca   25
# 2    3   NaN  -    6  NaN   LEIPHEIMER LeviUS Postal Service   27
# 3    4   NaN  -    1  NaN     HERAS RobertoUS Postal Service   27
# 4    5   NaN  -   29  NaN    MERCADO Juan MigueliBanesto.com   23
#
#                    Team  UCI    Pnt Unnamed: 10      Time Time won/lost  year
# 0               Festina  NaN  400.0         NaN  70:49:05            ..  2001
# 1  Kelme - Costa Blanca  NaN  290.0         NaN  0:470:47            ..  2001
# 2     US Postal Service  NaN  240.0         NaN  2:592:59            ..  2001
# 3     US Postal Service  NaN  220.0         NaN  3:563:56            ..  2001
# 4          iBanesto.com  NaN  200.0         NaN  5:455:45            ..  2001

# %%
gc.reset_index(drop = True, inplace = True)
gc.drop(['Prev', '▼▲', 'BIB', 'H2H', 'UCI', 'Pnt', 'Unnamed: 10', 'Time won/lost'], axis = 1, inplace = True)

# %%
gc[gc['Team'].isnull()]
# Out:
#      Rnk                          Rider  Age Team            Time  year
# 68    69            VÁZQUEZ José Manuel   26  NaN  1:47:141:47:14  2001
# 79    80     PEREZ CUAPIO Julio Alberto   24  NaN  2:02:072:02:07  2001
# 90    91               PEÑA Victor Hugo   27  NaN  2:17:512:17:51  2001
# 129  130  CARNEIRO SILVA Carlos Alberto   31  NaN  2:57:202:57:20  2001
# 233   95                   REISS Andris   24  NaN  2:42:532:42:53  2002
# 260  122              GUERRA Alessandro   28  NaN  3:24:433:24:43  2002

# %%
# Same tactic as before.
gc['Rider'] = gc.apply(lambda x: str(x.Rider).removesuffix(str(x.Team)), axis = 1)

# %%
def clean_time_gc(row):
    if row['Time'].startswith(','):
        return np.nan
    elif row['Rnk'] == 1:
        return row['Time']
    else:
        t = row['Time']
        return '+' + t[:int(len(t) / 2)]
    
gc['Time'] = gc.apply(clean_time_gc, axis = 1)
gc['Time'].fillna(method = 'ffill', inplace = True)

# %%
gc
# Out:
#       Rnk                Rider  Age                   Team      Time  year
# 0       1    CASERO Ángel Luis   29                Festina  70:49:05  2001
# 1       2        SEVILLA Óscar   25   Kelme - Costa Blanca     +0:47  2001
# 2       3      LEIPHEIMER Levi   27      US Postal Service     +2:59  2001
# 3       4        HERAS Roberto   27      US Postal Service     +3:56  2001
# 4       5  MERCADO Juan Miguel   23           iBanesto.com     +5:45  2001
# ...   ...                  ...  ...                    ...       ...   ...
# 3225  130  VAN DEN BERG Julius   25  EF Education-EasyPost  +5:15:43  2022
# 3226  131         OLIVEIRA Ivo   26      UAE Team Emirates  +5:19:55  2022
# 3227  132          MERLIER Tim   29     Alpecin-Deceuninck  +5:21:23  2022
# 3228  133            MAS Lluís   32          Movistar Team  +5:27:42  2022
# 3229  134       CIMOLAI Davide   33                Cofidis  +5:31:26  2022
#
# [3230 rows x 6 columns]

# %%
points.head()
# Out:
#   Rnk  Prev ▼▲  BIB  H2H                                Rider  Age  \
# 0   1   1.0  -   27  NaN       JIMÉNEZ José MaríaiBanesto.com   30
# 1   2   NaN  -  201  NaN               ZABEL ErikTeam Telekom   31
# 2   3   NaN  -    6  NaN     LEIPHEIMER LeviUS Postal Service   27
# 3   4   NaN  -  102  NaN  BOTERO SantiagoKelme - Costa Blanca   28
# 4   5   NaN  -  101  NaN    SEVILLA ÓscarKelme - Costa Blanca   25
#
#                    Team  UCI   Pnt  Points Today  year
# 0          iBanesto.com  NaN  80.0   130.0  +130  2001
# 1          Team Telekom  NaN  20.0   125.0  +125  2001
# 2     US Postal Service  NaN  10.0   115.0  +115  2001
# 3  Kelme - Costa Blanca  NaN   NaN   102.0  +102  2001
# 4  Kelme - Costa Blanca  NaN   NaN   101.0  +101  2001

# %%
points.reset_index(drop = True, inplace = True)
points.drop(['Prev', '▼▲', 'BIB', 'H2H', 'UCI', 'Pnt', 'Today'], axis = 1, inplace = True)

# %%
points['Rider'] = points.apply(lambda x: str(x.Rider).removesuffix(str(x.Team)), axis = 1)

# %%
# No value in entries with no points.
points = points.loc[points['Points'].notnull(), :]

# %%
kom.head()
# Out:
#    Rnk  Prev ▼▲    BIB  H2H                               Rider   Age  \
# 0  1.0   1.0  -   27.0  NaN      JIMÉNEZ José MaríaiBanesto.com  30.0
# 1  2.0   NaN  -  147.0  NaN  MØLLER Claus MichaelMilaneza - MSS  32.0
# 2  3.0   NaN  -   29.0  NaN     MERCADO Juan MigueliBanesto.com  23.0
# 3  4.0   NaN  -  101.0  NaN   SEVILLA ÓscarKelme - Costa Blanca  25.0
# 4  5.0   NaN  -    2.0  NaN  RUBIERA José LuisUS Postal Service  28.0
#
#                    Team  UCI   Pnt  Points Today  year    # Time
# 0          iBanesto.com  NaN  80.0     NaN     -  2001  NaN  NaN
# 1        Milaneza - MSS  NaN  20.0     NaN     -  2001  NaN  NaN
# 2          iBanesto.com  NaN  10.0     NaN     -  2001  NaN  NaN
# 3  Kelme - Costa Blanca  NaN   NaN     NaN     -  2001  NaN  NaN
# 4     US Postal Service  NaN   NaN     NaN     -  2001  NaN  NaN

# %%
kom.reset_index(drop = True, inplace = True)
kom.drop(['Prev', '▼▲', 'BIB', 'H2H', 'UCI', 'Pnt', 'Today', '#', 'Time'], axis = 1, inplace = True)

# %%
kom['Rider'] = kom.apply(lambda x: str(x.Rider).removesuffix(str(x.Team)), axis = 1)

# %%
kom = kom.loc[kom['Points'].notnull(), :]

# %% [markdown]
# ## Save Classifications Data

# %%
gc.to_csv('gc', index = False)
points.to_csv('points', index = False)
kom.to_csv('kom', index = False)
